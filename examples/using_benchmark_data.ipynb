# %% [markdown]
# # Using Benchmark Systems
#
# This notebook demonstrates how to use the `data` module to access remediated benchmark system inputs ready for use with the OpenFE toolkit.
#
# The module provides a convenient factory method to load benchmark systems with properly organized protein structures, ligands with different partial charge types, optional cofactors, and network mappings.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary functions from the module:

# %%
from openfe_benchmarks.data import (
    get_benchmark_data_system,
    list_benchmark_sets,
    list_data_systems,
    get_benchmark_set_data_systems,
    PARTIAL_CHARGE_TYPES,
    BenchmarkIndex,
)

# %% [markdown]
# ## Discovering Available Benchmark Sets
#
# The module automatically discovers all available benchmark sets in the directory structure. Let's see what's available:

# %%
# List all available benchmark sets
benchmark_sets = list_benchmark_sets()
print(f"Available benchmark sets ({len(benchmark_sets)}):")
for bset in benchmark_sets:
    print(f"  - {bset}")
# Out:
# Available benchmark sets (8):
#   - charge_annihilation_set
#   - fragments
#   - jacs_set
#   - janssen_bace
#   - mcs_docking_set
#   - merck
#   - miscellaneous_set
#   - water_set

# %%
index = BenchmarkIndex()
all_systems = index.get_all_systems()
for bset, systems in all_systems.items():
    print(bset)
    for bsys in systems:
        print("- ",bsys)
# Out:
# charge_annihilation_set
# -  cdk2
# -  dlk
# -  egfr
# -  ephx2
# -  irak4_s2
# -  irak4_s3
# -  itk
# -  jak1
# -  jnk1
# -  ptp1b
# -  thrombin
# -  tyk2
# fragments
# -  hsp90_2rings
# -  hsp90_single_ring
# -  jak2_set1
# -  jak2_set2
# -  liga
# -  mcl1
# -  mup1
# -  p38
# -  t4_lysozyme
# jacs_set
# -  bace
# -  cdk2
# -  jnk1
# -  mcl1
# -  p38
# -  ptp1b
# -  thrombin
# -  tyk2
# janssen_bace
# -  bace_ciordia_prospective
# -  bace_p3_arg368_in
# -  ciordia_retro
# -  keranen_p2
# mcs_docking_set
# -  hne
# -  renin
# merck
# -  cdk8
# -  cmet
# -  eg5
# -  hif2a
# -  pfkfb3
# -  shp2
# -  syk
# -  tnks2
# miscellaneous_set
# -  btk
# -  cdk8
# -  faah
# -  galectin
# -  hiv1_protease
# water_set
# -  brd4
# -  chk1
# -  hsp90_kung
# -  hsp90_woodhead
# -  scyt_dehyd
# -  taf12
# -  thrombin
# -  urokinase

# %% [markdown]
# Also get systems that are compatible with a given calculation type: rbfe, abfe, rsfe, asfe

# %%
rbfe_systems = index.get_systems_for_calculation('rbfe')
for bset, systems in rbfe_systems.items():
    print(bset)
    for bsys in systems:
        print("- ",bsys)
# Out:
# charge_annihilation_set
# -  cdk2
# -  dlk
# -  egfr
# -  ephx2
# -  irak4_s2
# -  irak4_s3
# -  itk
# -  jak1
# -  jnk1
# -  ptp1b
# -  thrombin
# -  tyk2
# fragments
# -  hsp90_2rings
# -  hsp90_single_ring
# -  jak2_set1
# -  jak2_set2
# -  liga
# -  mcl1
# -  mup1
# -  p38
# -  t4_lysozyme
# jacs_set
# -  bace
# -  cdk2
# -  jnk1
# -  mcl1
# -  p38
# -  ptp1b
# -  thrombin
# -  tyk2
# janssen_bace
# -  bace_ciordia_prospective
# -  bace_p3_arg368_in
# -  ciordia_retro
# -  keranen_p2
# mcs_docking_set
# -  hne
# -  renin
# merck
# -  cdk8
# -  cmet
# -  eg5
# -  hif2a
# -  pfkfb3
# -  shp2
# -  syk
# -  tnks2
# miscellaneous_set
# -  btk
# -  cdk8
# -  faah
# -  galectin
# -  hiv1_protease
# water_set
# -  brd4
# -  chk1
# -  hsp90_kung
# -  hsp90_woodhead
# -  scyt_dehyd
# -  taf12
# -  thrombin
# -  urokinase

# %% [markdown]
# ## Exploring Systems in a Benchmark Set
#
# Each benchmark set contains multiple systems. Let's explore what's available in the `jacs_set`:

# %%
# List systems in the jacs_set
jacs_systems = list_data_systems('jacs_set')
print(f"Systems in 'jacs_set' ({len(jacs_systems)}):")
for system in jacs_systems:
    print(f"  - {system}")
# Out:
# Systems in 'jacs_set' (8):
#   - bace
#   - cdk2
#   - jnk1
#   - mcl1
#   - p38
#   - ptp1b
#   - thrombin
#   - tyk2

# %% [markdown]
# Let's also look at the `fragments` benchmark set:

# %%
fragment_systems = list_data_systems('fragments')
print(f"Systems in 'fragments' ({len(fragment_systems)}):")
for system in fragment_systems:
    print(f"  - {system}")
# Out:
# Systems in 'fragments' (7):
#   - hsp90_2rings
#   - hsp90_single_ring
#   - jak2_set1
#   - jak2_set2
#   - liga
#   - mup1
#   - p38

# %% [markdown]
# ## Loading a Benchmark System
#
# Now let's load a specific benchmark system using the factory method. We'll use the HNE system from the MCS Docking set:

# %%
p38_system = get_benchmark_data_system('mcs_docking_set', 'hne')
p38_system.__dict__
# Out:
# 2026-02-02 13:35:04 | INFO     | Loaded system 'hne' from benchmark set 'mcs_docking_set' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.
# {'name': 'hne',
#  'benchmark_set': 'mcs_docking_set',
#  'protein': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/protein.pdb'),
#  'ligands': {'openeye_am1bcc': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_openeye_am1bcc.sdf'),
#   'nagl_openff-gnn-am1bcc-1.0.0.pt': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_nagl_openff-gnn-am1bcc-1.0.0.pt.sdf'),
#   'no_charges': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands.sdf'),
#   'antechamber_am1bcc': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_antechamber_am1bcc.sdf'),
#   'openeye_am1bccelf10': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_openeye_am1bccelf10.sdf')},
#  'cofactors': {'antechamber_am1bcc': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/cofactors_antechamber_am1bcc.sdf'),
#   'openeye_am1bccelf10': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/cofactors_openeye_am1bccelf10.sdf'),
#   'nagl_openff-gnn-am1bcc-1.0.0.pt': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/cofactors_nagl_openff-gnn-am1bcc-1.0.0.pt.sdf'),
#   'no_charges': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/cofactors.sdf'),
#   'openeye_am1bcc': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/cofactors_openeye_am1bcc.sdf')},
#  'network': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/industry_benchmarks_network.json')}

# %% [markdown]
# ## Accessing System Components
#
# The `BenchmarkData` object provides easy access to all components:

# %% [markdown]
# ### System Metadata

# %%
print(f"System name: {p38_system.name}")
print(f"Benchmark set: {p38_system.benchmark_set}")
# Out:
# System name: hne
# Benchmark set: mcs_docking_set

# %% [markdown]
# ### Protein Structure

# %%
print(f"Protein PDB file: {p38_system.protein}")
print(f"File exists: {p38_system.protein.exists()}")
print(f"File size: {p38_system.protein.stat().st_size / 1024:.2f} KB")
# Out:
# Protein PDB file: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/protein.pdb
# File exists: True
# File size: 311.10 KB

# %% [markdown]
# ### Ligands with Different Partial Charges
#
# The system can contain ligands with different partial charge types. Let's see what's available:

# %%
print(f"Available partial charge types in this module: {PARTIAL_CHARGE_TYPES}")
print(f"\nLigand files available for P38 system:")
for charge_type, ligand_path in p38_system.ligands.items():
    print(f"  - {charge_type}: {ligand_path.name}")
# Out:
# Available partial charge types in this module: ['antechamber_am1bcc', 'nagl_openff-gnn-am1bcc-1.0.0.pt', 'openeye_am1bcc', 'openeye_am1bccelf10']
#
# Ligand files available for P38 system:
#   - openeye_am1bcc: ligands_openeye_am1bcc.sdf
#   - nagl_openff-gnn-am1bcc-1.0.0.pt: ligands_nagl_openff-gnn-am1bcc-1.0.0.pt.sdf
#   - no_charges: ligands.sdf
#   - antechamber_am1bcc: ligands_antechamber_am1bcc.sdf
#   - openeye_am1bccelf10: ligands_openeye_am1bccelf10.sdf

# %% [markdown]
# ### Accessing Specific Charge Type

# %%
# Get the path to ligands with AM1-BCC charges from antechamber
am1bcc_ligands = p38_system.ligands['antechamber_am1bcc']
print(f"AM1-BCC ligands: {am1bcc_ligands}")

# Get the path to ligands with OpenEye AM1-BCC ELF10 charges
elf10_ligands = p38_system.ligands['openeye_am1bccelf10']
print(f"ELF10 ligands: {elf10_ligands}")
# Out:
# AM1-BCC ligands: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_antechamber_am1bcc.sdf
# ELF10 ligands: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/benchmark_systems/mcs_docking_set/hne/ligands_openeye_am1bccelf10.sdf

# %% [markdown]
# ### Cofactors
#
# Some systems may include cofactors. Let's check:

# %%
if p38_system.cofactors:
    print("Cofactor files available:")
    for charge_type, cofactor_path in p38_system.cofactors.items():
        print(f"  - {charge_type}: {cofactor_path.name}")
else:
    print("No cofactors for this system.")
# Out:
# Cofactor files available:
#   - antechamber_am1bcc: cofactors_antechamber_am1bcc.sdf
#   - openeye_am1bccelf10: cofactors_openeye_am1bccelf10.sdf
#   - nagl_openff-gnn-am1bcc-1.0.0.pt: cofactors_nagl_openff-gnn-am1bcc-1.0.0.pt.sdf
#   - no_charges: cofactors.sdf
#   - openeye_am1bcc: cofactors_openeye_am1bcc.sdf

# %% [markdown]
# ### Networks
#
# Systems include network files (e.g., LOMAP networks):

# %%
print(f"Network files {p38_system.network.name} is {p38_system.network.stat().st_size / 1024:.2f} KB")
# Out:
# Network files industry_benchmarks_network.json is 162.91 KB

# %% [markdown]
# ## Working with Multiple Systems
#
# Let's load and compare multiple systems from the same benchmark set:

# %%
# Load multiple systems
systems = get_benchmark_set_data_systems('jacs_set')

# Compare them
print("System comparison:")
print(f"{'System':<10} {'Networks':<10} {'Cofactors'} {'Charge Types':<30}")
print("="*70)
for name, system in systems.items():
    charge_types = ', '.join(system.ligands.keys())
    has_cofactors = 'Yes' if system.cofactors else 'No'
    has_network = 'Yes' if system.network else 'No'
    print(f"{name:<10} {has_network:<10} {has_cofactors:<10} {charge_types:<30}")
# Out:
# 2026-02-02 13:35:04 | INFO     | Loaded system 'bace' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cdk2' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jnk1' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'mcl1' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'p38' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'ptp1b' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'thrombin' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'tyk2' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# System comparison:
# System     Networks   Cofactors Charge Types
# ======================================================================
# bace       Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# cdk2       Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# jnk1       Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# mcl1       Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# p38        Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# ptp1b      Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# thrombin   Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10
# tyk2       Yes        No         openeye_am1bcc, nagl_openff-gnn-am1bcc-1.0.0.pt, no_charges, antechamber_am1bcc, openeye_am1bccelf10

# %% [markdown]
# ## Finding Systems with Cofactors
#
# Let's search through all benchmark sets to find systems that include cofactors:

# %%
systems_with_cofactors = []

for benchmark_set in list_benchmark_sets():
    for system_name in list_data_systems(benchmark_set):
        system = get_benchmark_data_system(benchmark_set, system_name)
        if system.cofactors:
            systems_with_cofactors.append((benchmark_set, system_name, system))

if systems_with_cofactors:
    print(f"Found {len(systems_with_cofactors)} system(s) with cofactors:")
    for bset, sname, system in systems_with_cofactors:
        print(f"\n  {bset}/{sname}:")
        for charge_type in system.cofactors.keys():
            print(f"    - {charge_type} charges available")
else:
    print("No systems with cofactors found.")
# Out:
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cdk2' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'dlk' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'egfr' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'ephx2' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'irak4_s2' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'irak4_s3' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'itk' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jak1' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jnk1' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'ptp1b' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'thrombin' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'tyk2' from benchmark set 'charge_annihilation_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'hsp90_2rings' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'hsp90_single_ring' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jak2_set1' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jak2_set2' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'liga' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'mup1' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'p38' from benchmark set 'fragments' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'bace' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cdk2' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'jnk1' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'mcl1' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'p38' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'ptp1b' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'thrombin' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'tyk2' from benchmark set 'jacs_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'bace_ciordia_prospective' from benchmark set 'janssen_bace' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'bace_p3_arg368_in' from benchmark set 'janssen_bace' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'ciordia_retro' from benchmark set 'janssen_bace' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'keranen_p2' from benchmark set 'janssen_bace' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'hne' from benchmark set 'mcs_docking_set' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'renin' from benchmark set 'mcs_docking_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cdk8' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cmet' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'eg5' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'hif2a' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'pfkfb3' from benchmark set 'merck' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'shp2' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'syk' from benchmark set 'merck' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'tnks2' from benchmark set 'merck' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'btk' from benchmark set 'miscellaneous_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'cdk8' from benchmark set 'miscellaneous_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'faah' from benchmark set 'miscellaneous_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:04 | INFO     | Loaded system 'galectin' from benchmark set 'miscellaneous_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:05 | INFO     | Loaded system 'hiv1_protease' from benchmark set 'miscellaneous_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# 2026-02-02 13:35:05 | INFO     | Loaded system 'brd4' from benchmark set 'water_set' with 5 ligand file(s), and 0 cofactor file(s). Found protein file: True.
# Found 4 system(s) with cofactors:
#
#   charge_annihilation_set/thrombin:
#     - antechamber_am1bcc charges available
#     - openeye_am1bccelf10 charges available
#     - nagl_openff-gnn-am1bcc-1.0.0.pt charges available
#     - no_charges charges available
#     - openeye_am1bcc charges available
#
#   mcs_docking_set/hne:
#     - antechamber_am1bcc charges available
#     - openeye_am1bccelf10 charges available
#     - nagl_openff-gnn-am1bcc-1.0.0.pt charges available
#     - no_charges charges available
#     - openeye_am1bcc charges available
#
#   merck/pfkfb3:
#     - antechamber_am1bcc charges available
#     - openeye_am1bccelf10 charges available
#     - nagl_openff-gnn-am1bcc-1.0.0.pt charges available
#     - no_charges charges available
#     - openeye_am1bcc charges available
#
#   merck/tnks2:
#     - antechamber_am1bcc charges available
#     - openeye_am1bccelf10 charges available
#     - nagl_openff-gnn-am1bcc-1.0.0.pt charges available
#     - no_charges charges available
#     - openeye_am1bcc charges available

# %% [markdown]
# ## Using with OpenFE
#
# Here's how you would typically use these paths with OpenFE to load the actual molecular structures:

# %%
from openfe import ProteinComponent, SmallMoleculeComponent, LigandNetwork
from rdkit import Chem

# Load a benchmark system that has network files
# Using HNE from mcs_docking_set which has networks, cofactors, and charged ligands
system = get_benchmark_data_system('mcs_docking_set', 'hne')
# Out:
# 2026-02-02 13:35:40 | INFO     | Loaded system 'hne' from benchmark set 'mcs_docking_set' with 5 ligand file(s), and 5 cofactor file(s). Found protein file: True.

# %%
# Load protein
protein = ProteinComponent.from_pdb_file(str(system.protein))
print(f"Loaded protein: {protein}")
print(f"  Number of atoms: {protein.to_rdkit().GetNumAtoms()}")
# Out:
# Loaded protein: ProteinComponent(name=)
#   Number of atoms: 3804

# %%
# Check available ligand files
print(f"\nAvailable ligand files for {system.name}:")
for charge_type in system.ligands.keys():
    print(f"  - {charge_type}")

# Load ligands without charges first (most reliable)
# Then OpenFE can assign charges during setup
print(f"\nLoading ligands from: {system.ligands['no_charges'].name}")

ligand_supplier = Chem.SDMolSupplier(str(system.ligands['no_charges']), removeHs=False)
ligands = []
for i, mol in enumerate(ligand_supplier):
    if mol is not None:
        try:
            ligands.append(SmallMoleculeComponent(mol))
        except Exception as e:
            print(f"  Warning: Skipping molecule {i+1} due to error: {e}")

print(f"\nSuccessfully loaded {len(ligands)} ligands")

# Show details of first few ligands
print("\nFirst 3 ligands:")
for i, ligand in enumerate(ligands[:3], 1):
    rdkit_mol = ligand.to_rdkit()
    print(f"  {i}. {ligand.name} - {rdkit_mol.GetNumAtoms()} atoms, {rdkit_mol.GetNumBonds()} bonds")
# Out:
# Available ligand files for hne:
#   - openeye_am1bcc
#   - nagl_openff-gnn-am1bcc-1.0.0.pt
#   - no_charges
#   - antechamber_am1bcc
#   - openeye_am1bccelf10
#
# Loading ligands from: ligands.sdf
#
# Successfully loaded 17 ligands
#
# First 3 ligands:
#   1. 6 - 55 atoms, 58 bonds
#   2. 14 - 49 atoms, 51 bonds
#   3. 15 - 56 atoms, 58 bonds

# %%
# Load network if available
if system.network is not None:
    print(f"\n{'='*60}")
    print(f"Loading network from: {system.network.name}")
    
    # Load network using from_json with file parameter (pass the file path directly)
    network = LigandNetwork.from_json(file=str(system.network))
    
    print(f"  Network loaded successfully!")
    print(f"  Network nodes: {len(network.nodes)}")
    print(f"  Network edges: {len(network.edges)}")
    
    # Show some example edges
    print("\nFirst 3 network edges:")
    for i, edge in enumerate(list(network.edges)[:3], 1):
        print(f"  {i}. {edge.componentA.name} <-> {edge.componentB.name}")
        
    # Note: The network contains its own SmallMoleculeComponent objects
    # which may differ slightly from the ligands we loaded above
    print(f"\nNote: Network contains {len(network.nodes)} ligand(s) with embedded molecule data")
else:
    print("\nNo network files found for this system.")
# Out:
# ============================================================
# Loading network from: industry_benchmarks_network.json
#   Network loaded successfully!
#   Network nodes: 17
#   Network edges: 23
#
# First 3 network edges:
#   1. 15 <-> 17
#   2. 25 <-> 27
#   3. 14 <-> 17
#
# Note: Network contains 17 ligand(s) with embedded molecule data

# %%
# Load cofactors if available
cofactors = []
if system.cofactors:
    print(f"\n{'='*60}")
    print(f"Loading cofactors from: {system.cofactors['no_charges'].name}")
    cofactor_supplier = Chem.SDMolSupplier(str(system.cofactors['no_charges']), removeHs=False)
    for mol in cofactor_supplier:
        if mol is not None:
            print(mol)
            try:
                cofactors.append(SmallMoleculeComponent(mol, name=mol.GetProp("s_m_entry_name")))
            except Exception as e:
                print(f"  Warning: Skipping cofactor due to error: {e}")
    print(f"Successfully loaded {len(cofactors)} cofactor(s)")
# Out:
# ============================================================
# Loading cofactors from: cofactors.sdf
# <rdkit.Chem.rdchem.Mol object at 0x30620e9d0>
# Successfully loaded 1 cofactor(s)
# /Users/jenniferclark/bin/gufe/gufe/components/explicitmoleculecomponent.py:27: UserWarning: Component being renamed from EPE-1 to Structure11.
#   warnings.warn(f"Component being renamed from {rdkit_name} to {name}.")

# %%
print(f"\n{'='*60}")
print(f"System components ready for OpenFE:")
print(f"  Protein: {protein.name if protein.name else 'unnamed'} ({system.protein.name})")
print(f"  Ligands: {len(ligands)} molecules loaded from SDF")
print(f"  Cofactors: {len(cofactors)} molecule(s)")
print(f"  Network: {len(network.edges) if network else 0} transformations")
# Out:
# ============================================================
# System components ready for OpenFE:
#   Protein: unnamed (protein.pdb)
#   Ligands: 17 molecules loaded from SDF
#   Cofactors: 1 molecule(s)
#   Network: 23 transformations

# %% [markdown]
# ## Error Handling
#
# The module provides helpful error messages when you try to access non-existent benchmark sets or systems:

# %%
# Try to load a non-existent benchmark set
try:
    system = get_benchmark_data_system('nonexistent_set', 'p38')
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: Benchmark set 'nonexistent_set' not found. Available benchmark sets: ['charge_annihilation_set', 'fragments', 'jacs_set', 'janssen_bace', 'mcs_docking_set', 'merck', 'miscellaneous_set', 'water_set']

# %%
# Try to load a non-existent system
try:
    system = get_benchmark_data_system('jacs_set', 'nonexistent_system')
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: System 'nonexistent_system' not found in benchmark set 'jacs_set'. Available systems in 'jacs_set': ['bace', 'cdk2', 'jnk1', 'mcl1', 'p38', 'ptp1b', 'thrombin', 'tyk2']
