# %% [markdown]
# # Using Industry Benchmark Systems
#
# This notebook demonstrates how to use the `industry_benchmark_systems` module to access remediated benchmark system inputs ready for use with the OpenFE toolkit.
#
# The module provides a convenient factory method to load benchmark systems with properly organized protein structures, ligands with different partial charge types, optional cofactors, and network mappings.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary functions from the module:

# %%
from openfe_benchmarks.data import (
    get_benchmark_system,
    list_benchmark_sets,
    list_systems,
    PARTIAL_CHARGE_TYPES,
)

# %% [markdown]
# ## Discovering Available Benchmark Sets
#
# The module automatically discovers all available benchmark sets in the directory structure. Let's see what's available:

# %%
# List all available benchmark sets
benchmark_sets = list_benchmark_sets()
print(f"Available benchmark sets ({len(benchmark_sets)}):")
for bset in benchmark_sets:
    print(f"  - {bset}")
# Out:
# Available benchmark sets (4):
#   - fragments
#   - jacs_set
#   - janssen_bace
#   - mcs_docking_set

# %% [markdown]
# ## Exploring Systems in a Benchmark Set
#
# Each benchmark set contains multiple systems. Let's explore what's available in the `jacs_set`:

# %%
# List systems in the jacs_set
jacs_systems = list_systems('jacs_set')
print(f"Systems in 'jacs_set' ({len(jacs_systems)}):")
for system in jacs_systems:
    print(f"  - {system}")
# Out:
# Systems in 'jacs_set' (8):
#   - bace
#   - cdk2
#   - jnk1
#   - mcl1
#   - p38
#   - ptp1b
#   - thrombin
#   - tyk2

# %% [markdown]
# Let's also look at the `fragments` benchmark set:

# %%
fragment_systems = list_systems('fragments')
print(f"Systems in 'fragments' ({len(fragment_systems)}):")
for system in fragment_systems:
    print(f"  - {system}")
# Out:
# Systems in 'fragments' (9):
#   - hsp90_2rings
#   - hsp90_single_ring
#   - jak2_set1
#   - jak2_set2
#   - liga
#   - mcl1
#   - mup1
#   - p38
#   - t4_lysozyme

# %% [markdown]
# ## Loading a Benchmark System
#
# Now let's load a specific benchmark system using the factory method. We'll use the P38 system from the JACS set:

# %%
# Load the P38 system
p38_system = get_benchmark_system('jacs_set', 'p38')
p38_system.__dict__
# Out:
# 2026-01-21 08:49:52.891 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'p38' from 'jacs_set'...
# 2026-01-21 08:49:52.891 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:52.891 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:52.893 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:52.894 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:52.894 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'p38' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# {'name': 'p38',
#  'benchmark_set': 'jacs_set',
#  'protein': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/protein.pdb'),
#  'ligands': {'openeye_elf10': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/ligands_openeye_elf10.sdf'),
#   'antechamber_am1bcc': PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/ligands_antechamber_am1bcc.sdf')},
#  'cofactors': {},
#  'mappings': [PosixPath('/Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/lomap_network.graphml')]}

# %% [markdown]
# ## Accessing System Components
#
# The `BenchmarkSystem` object provides easy access to all components:

# %% [markdown]
# ### System Metadata

# %%
print(f"System name: {p38_system.name}")
print(f"Benchmark set: {p38_system.benchmark_set}")
# Out:
# System name: p38
# Benchmark set: jacs_set

# %% [markdown]
# ### Protein Structure

# %%
print(f"Protein PDB file: {p38_system.protein}")
print(f"File exists: {p38_system.protein.exists()}")
print(f"File size: {p38_system.protein.stat().st_size / 1024:.2f} KB")
# Out:
# Protein PDB file: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/protein.pdb
# File exists: True
# File size: 547.42 KB

# %% [markdown]
# ### Ligands with Different Partial Charges
#
# The system can contain ligands with different partial charge types. Let's see what's available:

# %%
print(f"Available partial charge types in this module: {PARTIAL_CHARGE_TYPES}")
print(f"\nLigand files available for P38 system:")
for charge_type, ligand_path in p38_system.ligands.items():
    print(f"  - {charge_type}: {ligand_path.name}")
# Out:
# Available partial charge types in this module: ['antechamber_am1bcc', 'openeye_elf10']
#
# Ligand files available for P38 system:
#   - openeye_elf10: ligands_openeye_elf10.sdf
#   - antechamber_am1bcc: ligands_antechamber_am1bcc.sdf

# %% [markdown]
# ### Accessing Specific Charge Type

# %%
# Get the path to ligands with AM1-BCC charges
am1bcc_ligands = p38_system.ligands['antechamber_am1bcc']
print(f"AM1-BCC ligands: {am1bcc_ligands}")

# Get the path to ligands with ELF10 charges
elf10_ligands = p38_system.ligands['openeye_elf10']
print(f"ELF10 ligands: {elf10_ligands}")
# Out:
# AM1-BCC ligands: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/ligands_antechamber_am1bcc.sdf
# ELF10 ligands: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/ligands_openeye_elf10.sdf

# %% [markdown]
# ### Cofactors
#
# Some systems may include cofactors. Let's check:

# %%
if p38_system.cofactors:
    print("Cofactor files available:")
    for charge_type, cofactor_path in p38_system.cofactors.items():
        print(f"  - {charge_type}: {cofactor_path.name}")
else:
    print("No cofactors for this system.")
# Out:
# No cofactors for this system.

# %% [markdown]
# ### Network Mappings
#
# Systems include network mapping files (e.g., LOMAP networks):

# %%
print(f"Network mapping files ({len(p38_system.mappings)}):")
for mapping_path in p38_system.mappings:
    print(f"  - {mapping_path.name}")
    print(f"    Size: {mapping_path.stat().st_size / 1024:.2f} KB")
# Out:
# Network mapping files (1):
#   - lomap_network.graphml
#     Size: 269.85 KB

# %% [markdown]
# ## Working with Multiple Systems
#
# Let's load and compare multiple systems from the same benchmark set:

# %%
# Load multiple systems
systems = {}
for system_name in ['p38', 'tyk2', 'ptp1b']:
    systems[system_name] = get_benchmark_system('jacs_set', system_name)

# Compare them
print("System comparison:")
print(f"{'System':<15} {'Charge Types':<30} {'Mappings':<10} {'Cofactors'}")
print("="*70)
for name, system in systems.items():
    charge_types = ', '.join(system.ligands.keys())
    has_cofactors = 'Yes' if system.cofactors else 'No'
    print(f"{name:<15} {charge_types:<30} {len(system.mappings):<10} {has_cofactors}")
# Out:
# 2026-01-21 08:49:24.710 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'p38' from 'jacs_set'...
# 2026-01-21 08:49:24.711 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.711 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.711 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.711 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.712 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'p38' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.715 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'tyk2' from 'jacs_set'...
# 2026-01-21 08:49:24.715 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.715 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.716 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.716 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.716 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'tyk2' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.722 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'ptp1b' from 'jacs_set'...
# 2026-01-21 08:49:24.730 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.732 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.733 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.734 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.745 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'ptp1b' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# System comparison:
# System          Charge Types                   Mappings   Cofactors
# ======================================================================
# p38             openeye_elf10, antechamber_am1bcc 1          No
# tyk2            openeye_elf10, antechamber_am1bcc 1          No
# ptp1b           openeye_elf10, antechamber_am1bcc 1          No

# %% [markdown]
# ## Finding Systems with Cofactors
#
# Let's search through all benchmark sets to find systems that include cofactors:

# %%
systems_with_cofactors = []

for benchmark_set in list_benchmark_sets():
    for system_name in list_systems(benchmark_set):
        system = get_benchmark_system(benchmark_set, system_name)
        if system.cofactors:
            systems_with_cofactors.append((benchmark_set, system_name, system))

if systems_with_cofactors:
    print(f"Found {len(systems_with_cofactors)} system(s) with cofactors:")
    for bset, sname, system in systems_with_cofactors:
        print(f"\n  {bset}/{sname}:")
        for charge_type in system.cofactors.keys():
            print(f"    - {charge_type} charges available")
else:
    print("No systems with cofactors found.")
# Out:
# 2026-01-21 08:49:24.767 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'hsp90_2rings' from 'fragments'...
# 2026-01-21 08:49:24.767 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.767 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.768 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.768 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.768 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'hsp90_2rings' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.769 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'hsp90_single_ring' from 'fragments'...
# 2026-01-21 08:49:24.769 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.769 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.770 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.770 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.770 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'hsp90_single_ring' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.772 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'jak2_set1' from 'fragments'...
# 2026-01-21 08:49:24.773 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.783 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.784 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.784 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.784 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'jak2_set1' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.785 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'jak2_set2' from 'fragments'...
# 2026-01-21 08:49:24.786 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.786 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.786 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.786 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.786 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'jak2_set2' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.788 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'liga' from 'fragments'...
# 2026-01-21 08:49:24.788 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.788 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.788 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.789 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.789 | WARNING  | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:178 - Uncategorized file 'preparation_details.md' found in system 'liga' in benchmark set 'fragments'. This file will be ignored.
# 2026-01-21 08:49:24.789 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'liga' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.790 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'mcl1' from 'fragments'...
# 2026-01-21 08:49:24.790 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.791 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.791 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.791 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.791 | WARNING  | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:178 - Uncategorized file 'PREPARATION_DEATILS.md' found in system 'mcl1' in benchmark set 'fragments'. This file will be ignored.
# 2026-01-21 08:49:24.792 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'mcl1' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.793 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'mup1' from 'fragments'...
# 2026-01-21 08:49:24.794 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.794 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.794 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.795 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.795 | WARNING  | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:178 - Uncategorized file 'preparation_details.md' found in system 'mup1' in benchmark set 'fragments'. This file will be ignored.
# 2026-01-21 08:49:24.795 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'mup1' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.796 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'p38' from 'fragments'...
# 2026-01-21 08:49:24.797 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.797 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.797 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.797 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.798 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'p38' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.799 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 't4_lysozyme' from 'fragments'...
# 2026-01-21 08:49:24.799 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.799 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.799 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.799 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.800 | WARNING  | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:178 - Uncategorized file 'PREPARATION_DEATILS.md' found in system 't4_lysozyme' in benchmark set 'fragments'. This file will be ignored.
# 2026-01-21 08:49:24.800 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 't4_lysozyme' from benchmark set 'fragments' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.801 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'bace' from 'jacs_set'...
# 2026-01-21 08:49:24.802 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.802 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.802 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.803 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.803 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'bace' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.804 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'cdk2' from 'jacs_set'...
# 2026-01-21 08:49:24.805 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.805 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.805 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.805 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.805 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'cdk2' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.806 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'jnk1' from 'jacs_set'...
# 2026-01-21 08:49:24.807 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.807 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.807 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.807 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.807 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'jnk1' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.808 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'mcl1' from 'jacs_set'...
# 2026-01-21 08:49:24.809 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.809 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.809 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.809 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.810 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'mcl1' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.811 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'p38' from 'jacs_set'...
# 2026-01-21 08:49:24.811 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.811 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.812 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.812 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.812 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'p38' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.813 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'ptp1b' from 'jacs_set'...
# 2026-01-21 08:49:24.813 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.813 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.813 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.814 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.814 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'ptp1b' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.815 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'thrombin' from 'jacs_set'...
# 2026-01-21 08:49:24.815 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.815 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.815 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.816 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.816 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'thrombin' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.817 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'tyk2' from 'jacs_set'...
# 2026-01-21 08:49:24.817 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.817 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.817 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.817 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.818 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'tyk2' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.819 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'ciordia_retro' from 'janssen_bace'...
# 2026-01-21 08:49:24.820 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.820 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.820 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.820 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.820 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'ciordia_retro' from benchmark set 'janssen_bace' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.821 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'keranen_p2' from 'janssen_bace'...
# 2026-01-21 08:49:24.822 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.822 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.822 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.822 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.822 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'keranen_p2' from benchmark set 'janssen_bace' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.824 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'hne' from 'mcs_docking_set'...
# 2026-01-21 08:49:24.824 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:144 - Found cofactors with antechamber_am1bcc charges: cofactors_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.824 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.824 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.825 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.825 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.825 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:144 - Found cofactors with openeye_elf10 charges: cofactors_openeye_elf10.sdf
# 2026-01-21 08:49:24.825 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'hne' from benchmark set 'mcs_docking_set' with 2 ligand file(s), 2 cofactor file(s), and 1 mapping file(s).
# 2026-01-21 08:49:24.826 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'renin' from 'mcs_docking_set'...
# 2026-01-21 08:49:24.827 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.827 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.827 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.827 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.827 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'renin' from benchmark set 'mcs_docking_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# Found 1 system(s) with cofactors:
#
#   mcs_docking_set/hne:
#     - antechamber_am1bcc charges available
#     - openeye_elf10 charges available

# %% [markdown]
# ## Using with OpenFE
#
# Here's how you would typically use these paths with OpenFE to load the actual molecular structures:

# %%
# Example (uncomment if you have OpenFE installed):
# from openfe import ChemicalSystem, ProteinComponent, SmallMoleculeComponent
# from rdkit import Chem
# import MDAnalysis as mda

# Load the benchmark system
system = get_benchmark_system('jacs_set', 'p38')

# Load protein
# protein = ProteinComponent.from_pdb_file(str(system.protein))

# Load ligands with AM1-BCC charges
# ligand_supplier = Chem.SDMolSupplier(str(system.ligands['antechamber_am1bcc']))
# ligands = [SmallMoleculeComponent(mol) for mol in ligand_supplier if mol is not None]

print(f"System ready to use with OpenFE:")
print(f"  Protein: {system.protein}")
print(f"  Ligands: {system.ligands['antechamber_am1bcc']}")
print(f"  Network: {system.mappings[0] if system.mappings else 'N/A'}")
# Out:
# 2026-01-21 08:49:24.834 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:get_benchmark_system:254 - Loading benchmark system 'p38' from 'jacs_set'...
# 2026-01-21 08:49:24.834 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:151 - Found network mapping: lomap_network.graphml
# 2026-01-21 08:49:24.835 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with openeye_elf10 charges: ligands_openeye_elf10.sdf
# 2026-01-21 08:49:24.835 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:128 - Found ligands with antechamber_am1bcc charges: ligands_antechamber_am1bcc.sdf
# 2026-01-21 08:49:24.835 | DEBUG    | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:112 - Found protein: protein.pdb
# 2026-01-21 08:49:24.836 | INFO     | openfe_benchmarks.data.industry_benchmark_systems:_validate_and_load_system:198 - Loaded system 'p38' from benchmark set 'jacs_set' with 2 ligand file(s), 0 cofactor file(s), and 1 mapping file(s).
# System ready to use with OpenFE:
#   Protein: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/protein.pdb
#   Ligands: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/ligands_antechamber_am1bcc.sdf
#   Network: /Users/jenniferclark/bin/openfe-benchmarks/openfe_benchmarks/data/industry_benchmark_systems/jacs_set/p38/lomap_network.graphml

# %% [markdown]
# ## Error Handling
#
# The module provides helpful error messages when you try to access non-existent benchmark sets or systems:

# %%
# Try to load a non-existent benchmark set
try:
    system = get_benchmark_system('nonexistent_set', 'p38')
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: Benchmark set 'nonexistent_set' not found. Available benchmark sets: ['fragments', 'jacs_set', 'janssen_bace', 'mcs_docking_set']

# %%
# Try to load a non-existent system
try:
    system = get_benchmark_system('jacs_set', 'nonexistent_system')
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: System 'nonexistent_system' not found in benchmark set 'jacs_set'. Available systems in 'jacs_set': ['bace', 'cdk2', 'jnk1', 'mcl1', 'p38', 'ptp1b', 'thrombin', 'tyk2']

# %% [markdown]
# ## Summary
#
# The `industry_benchmark_systems` module provides:
#
# 1. **Easy discovery** of available benchmark sets and systems
# 2. **Organized access** to protein structures, ligands with different charge types, cofactors, and network mappings
# 3. **Validation** to ensure all required files are present and properly named
# 4. **Helpful error messages** when things go wrong
#
# ### Key Functions:
# - `list_benchmark_sets()` - List all available benchmark sets
# - `list_systems(benchmark_set)` - List all systems in a benchmark set
# - `get_benchmark_system(benchmark_set, system_name)` - Load a specific benchmark system
#
# ### BenchmarkSystem Attributes:
# - `name` - System name
# - `benchmark_set` - Benchmark set name
# - `protein` - Path to protein.pdb
# - `ligands` - Dictionary of charge_type: path to ligands_<charge_type>.sdf
# - `cofactors` - Dictionary of charge_type: path to cofactors_<charge_type>.sdf (may be empty)
# - `mappings` - List of paths to network mapping files

# %%
# Example of visualizing ligands (uncomment if you have RDKit installed):
# from rdkit import Chem
# from rdkit.Chem import AllChem, Draw

# Load a system
system = get_benchmark_system('jacs_set', 'tyk2')

# Load ligands with AM1-BCC charges
# ligand_supplier = Chem.SDMolSupplier(str(system.ligands['antechamber_am1bcc']), removeHs=False)
# ligands = [mol for mol in ligand_supplier if mol is not None]

# Generate 2D coordinates for visualization
# for ligand in ligands:
#     AllChem.Compute2DCoords(ligand)

# Display as grid
# Draw.MolsToGridImage(ligands[:12], molsPerRow=4, subImgSize=(200, 200))

print(f"System: {system.name}")
print(f"Ligand file: {system.ligands['antechamber_am1bcc']}")
print(f"File size: {system.ligands['antechamber_am1bcc'].stat().st_size / 1024:.2f} KB")

# %% [markdown]
# ## Visualizing Ligand Structures
#
# Let's visualize the ligands in a system using RDKit:

# %%
# Example of loading a network file (uncomment if you have OpenFE/gufe installed):
# from gufe import LigandNetwork

# Load a system with network mappings
system = get_benchmark_system('jacs_set', 'p38')

if system.mappings:
    print(f"Found {len(system.mappings)} network mapping file(s):")
    for mapping_file in system.mappings:
        print(f"  - {mapping_file.name}")
        
        # To load the network:
        # with open(mapping_file, 'r') as f:
        #     graphml_str = f.read()
        # network = LigandNetwork.from_graphml(graphml_str)
        # print(f"    Network has {len(network.nodes)} nodes and {len(network.edges)} edges")
else:
    print("No network mapping files found for this system.")

# %% [markdown]
# ## Loading Network Files
#
# The benchmark systems include pre-computed network mapping files (GraphML format). Let's see how to load and inspect them:
